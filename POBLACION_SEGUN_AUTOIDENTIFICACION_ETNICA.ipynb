# %% [markdown]
# <h1 style="text-align:center">Trabajo Final - Primer Bimestre</h1>
# ***
# * **POBLACION SEGÚN AUTOIDENTIFICACION ETNICA**
# ***
# Por medio de este trabajo se podrá visualizar la cantidad de mujeres y hombres, segun su **Autoidentificacion Etnica**(indigena, afroecuatoriano, montubio, mestizo, blanco u otro). Ademas de presentar tambien un porcentaje de hombres y mujeres bajo el mismo parametro y un total de personas. Tambien cuenta con un parametro que nos otorga una constante llamada indice de feminidad, la cual esta basada en la cantidad de por etnia sobre los hombres.
#
# Autores : **Jorge Hurtado - Jonathan Rosero**

# %%
import pandas as pd

# %%
pd.read_csv('./data/POBLACION_SEGUN_AUTOIDENTIFICACION_ETNICA.csv')
# Out:
#                ETNIA  MUJERES_NUMERO  MUJERES_%  HOMBRES_NUMERO  HOMBRES_%  \
# 0           indigena          517797        7.1          500379        7.0
# 1  afroecuatoriano/a          513112        7.0          528447        7.4
# 2         montubio/a          500115        6.8          570613        7.9
# 3          mestizo/a         5301654       72.6         5115645       71.3
# 4           blanco/a          448740        6.1          433643        6.0
# 5             otro/a           24398        0.3           28956        0.4
# 6              Total         7305816      100.0         7177683      100.0
#
#    INDICE_DE_FEMINIDAD
# 0                103.5
# 1                 97.1
# 2                 87.6
# 3                103.6
# 4                103.5
# 5                 84.3
# 6                101.8

# %%
tabla1 = pd.read_csv('./data/POBLACION_SEGUN_AUTOIDENTIFICACION_ETNICA.csv')

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="be985be0-a889-47cc-87a0-0d5e1835b96e">Loading BokehJS ...</span>
#     </div>

# %%
group1 = tabla1.groupby('ETNIA')

source = ColumnDataSource(group1)

source.data
# Out:
# {'ETNIA': array(['Total', 'afroecuatoriano/a', 'blanco/a', 'indigena', 'mestizo/a',
#         'montubio/a', 'otro/a'], dtype=object),
#  'HOMBRES_%_25%': array([ 100. ,    7.4,    6. ,    7. ,   71.3,    7.9,    0.4]),
#  'HOMBRES_%_50%': array([ 100. ,    7.4,    6. ,    7. ,   71.3,    7.9,    0.4]),
#  'HOMBRES_%_75%': array([ 100. ,    7.4,    6. ,    7. ,   71.3,    7.9,    0.4]),
#  'HOMBRES_%_count': array([ 1.,  1.,  1.,  1.,  1.,  1.,  1.]),
#  'HOMBRES_%_max': array([ 100. ,    7.4,    6. ,    7. ,   71.3,    7.9,    0.4]),
#  'HOMBRES_%_mean': array([ 100. ,    7.4,    6. ,    7. ,   71.3,    7.9,    0.4]),
#  'HOMBRES_%_min': array([ 100. ,    7.4,    6. ,    7. ,   71.3,    7.9,    0.4]),
#  'HOMBRES_%_std': array([ nan,  nan,  nan,  nan,  nan,  nan,  nan]),
#  'HOMBRES_NUMERO_25%': array([ 7177683.,   528447.,   433643.,   500379.,  5115645.,   570613.,
#            28956.]),
#  'HOMBRES_NUMERO_50%': array([ 7177683.,   528447.,   433643.,   500379.,  5115645.,   570613.,
#            28956.]),
#  'HOMBRES_NUMERO_75%': array([ 7177683.,   528447.,   433643.,   500379.,  5115645.,   570613.,
#            28956.]),
#  'HOMBRES_NUMERO_count': array([ 1.,  1.,  1.,  1.,  1.,  1.,  1.]),
#  'HOMBRES_NUMERO_max': array([ 7177683.,   528447.,   433643.,   500379.,  5115645.,   570613.,
#            28956.]),
#  'HOMBRES_NUMERO_mean': array([ 7177683.,   528447.,   433643.,   500379.,  5115645.,   570613.,
#            28956.]),
#  'HOMBRES_NUMERO_min': array([ 7177683.,   528447.,   433643.,   500379.,  5115645.,   570613.,
#            28956.]),
#  'HOMBRES_NUMERO_std': array([ nan,  nan,  nan,  nan,  nan,  nan,  nan]),
#  'INDICE_DE_FEMINIDAD_25%': array([ 101.8,   97.1,  103.5,  103.5,  103.6,   87.6,   84.3]),
#  'INDICE_DE_FEMINIDAD_50%': array([ 101.8,   97.1,  103.5,  103.5,  103.6,   87.6,   84.3]),
#  'INDICE_DE_FEMINIDAD_75%': array([ 101.8,   97.1,  103.5,  103.5,  103.6,   87.6,   84.3]),
#  'INDICE_DE_FEMINIDAD_count': array([ 1.,  1.,  1.,  1.,  1.,  1.,  1.]),
#  'INDICE_DE_FEMINIDAD_max': array([ 101.8,   97.1,  103.5,  103.5,  103.6,   87.6,   84.3]),
#  'INDICE_DE_FEMINIDAD_mean': array([ 101.8,   97.1,  103.5,  103.5,  103.6,   87.6,   84.3]),
#  'INDICE_DE_FEMINIDAD_min': array([ 101.8,   97.1,  103.5,  103.5,  103.6,   87.6,   84.3]),
#  'INDICE_DE_FEMINIDAD_std': array([ nan,  nan,  nan,  nan,  nan,  nan,  nan]),
#  'MUJERES_%_25%': array([ 100. ,    7. ,    6.1,    7.1,   72.6,    6.8,    0.3]),
#  'MUJERES_%_50%': array([ 100. ,    7. ,    6.1,    7.1,   72.6,    6.8,    0.3]),
#  'MUJERES_%_75%': array([ 100. ,    7. ,    6.1,    7.1,   72.6,    6.8,    0.3]),
#  'MUJERES_%_count': array([ 1.,  1.,  1.,  1.,  1.,  1.,  1.]),
#  'MUJERES_%_max': array([ 100. ,    7. ,    6.1,    7.1,   72.6,    6.8,    0.3]),
#  'MUJERES_%_mean': array([ 100. ,    7. ,    6.1,    7.1,   72.6,    6.8,    0.3]),
#  'MUJERES_%_min': array([ 100. ,    7. ,    6.1,    7.1,   72.6,    6.8,    0.3]),
#  'MUJERES_%_std': array([ nan,  nan,  nan,  nan,  nan,  nan,  nan]),
#  'MUJERES_NUMERO_25%': array([ 7305816.,   513112.,   448740.,   517797.,  5301654.,   500115.,
#            24398.]),
#  'MUJERES_NUMERO_50%': array([ 7305816.,   513112.,   448740.,   517797.,  5301654.,   500115.,
#            24398.]),
#  'MUJERES_NUMERO_75%': array([ 7305816.,   513112.,   448740.,   517797.,  5301654.,   500115.,
#            24398.]),
#  'MUJERES_NUMERO_count': array([ 1.,  1.,  1.,  1.,  1.,  1.,  1.]),
#  'MUJERES_NUMERO_max': array([ 7305816.,   513112.,   448740.,   517797.,  5301654.,   500115.,
#            24398.]),
#  'MUJERES_NUMERO_mean': array([ 7305816.,   513112.,   448740.,   517797.,  5301654.,   500115.,
#            24398.]),
#  'MUJERES_NUMERO_min': array([ 7305816.,   513112.,   448740.,   517797.,  5301654.,   500115.,
#            24398.]),
#  'MUJERES_NUMERO_std': array([ nan,  nan,  nan,  nan,  nan,  nan,  nan])}

# %%
from bokeh.layouts import gridplot

group1 = tabla1.groupby('ETNIA')

source = ColumnDataSource(group1)

options = dict(plot_width=800, plot_height=450, x_range=group1, tools="pan,wheel_zoom,box_zoom") 

graph1 = figure(title='POBLACION SEGUN AUTOIDENTIFICACION ETNICA', **options )

graph1.line(x='ETNIA', y='HOMBRES_NUMERO_mean', color="#FF7F50", legend='HOMBRES', source=source)
graph1.circle(x='ETNIA', y='HOMBRES_NUMERO_mean', color='#FF7F50', size=5.5, source=source)
graph1.line(x='ETNIA', y='MUJERES_NUMERO_mean', color="#9932CC", legend='MUJERES', source=source)
graph1.circle(x='ETNIA', y='MUJERES_NUMERO_mean', color="#9932CC", size=5.5, source=source)
graph = gridplot([[graph1]])

show(graph)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="54c86f7d-29dc-4d4e-935b-164d77c130e9"></div>
# </div>

# %%
from bokeh.layouts import gridplot

group1 = tabla1.groupby('ETNIA')

source = ColumnDataSource(group1)

options = dict(plot_width=800, plot_height=450, x_range=group1, tools="pan,wheel_zoom,box_zoom") 

graph1 = figure(title='POBLACION SEGUN AUTOIDENTIFICACION ETNICA', **options )

graph1.line(x='ETNIA', y='HOMBRES_%_mean', color="#7CFC00", legend='% HOMBRES', source=source)
graph1.circle(x='ETNIA', y='HOMBRES_%_mean', color='#7CFC00', size=5.5, source=source)
graph1.line(x='ETNIA', y='MUJERES_%_mean', color="#20B2AA", legend='% MUJERES', source=source)
graph1.circle(x='ETNIA', y='MUJERES_%_mean', color="#20B2AA", size=5.5, source=source)
graph = gridplot([[graph1]])

show(graph)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="c4e6e64a-ea7f-4493-ac0f-9af9f7e1963b"></div>
# </div>

# %%
group1 = tabla1.groupby('ETNIA')

source = ColumnDataSource(group1)

gph = figure(plot_height=250, plot_width=750, x_range=group1, title='POBLACION SEGUN AUTOIDENTIFICACION' )

gph.vbar(x='ETNIA', top='INDICE_DE_FEMINIDAD_mean', width=0.5, line_color="white", source=source)

gph.xgrid.grid_line_color = None
gph.xaxis.axis_label = "ETNIA - INDICE DE FEMINIDAD"
gph.y_range.start = 0

show(gph)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="b04e4285-a759-4482-b2fa-32f7324fb565"></div>
# </div>
